# %%
import cobaya
from cobaya.model import get_model

# %%
model = get_model("/home/camilo/cocoa/Cocoa/projects/cmb_gamma/EVALUATE1.yaml")
# Out:
# [model] *WARNING* Ignored blocks/options: ['output', 'sampler']
# [camb] `camb` module loaded successfully from /home/camilo/cocoa/Cocoa/.local/lib/python3.10/site-packages/camb
# [planck_2018_lowl.tt] `clik` module loaded successfully from /home/camilo/cocoa/Cocoa/.local/lib/python/site-packages/clik
# [planck_2020_hillipop.ttteee] Initialized!
# [planck_2020_lollipop.lowle] Initialized!
# [planck_2018_lensing.clik] `clik` module loaded successfully from /home/camilo/cocoa/Cocoa/.local/lib/python/site-packages/clik
# [mylike] Initializing
# [mylike] Initializing
# [model] *ERROR* requirement H0 is provided by more than one component: [mylike, camb]. Use 'provides' keyword to specify which provides it
# ---------------------------------------------------------------------------
# LoggedError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 model = get_model("/home/camilo/cocoa/Cocoa/projects/cmb_gamma/EVALUATE1.yaml")
#
# ...

# %%
random_point = model.prior.sample(ignore_external=True)[0]
sampled_params_names = model.parameterization.sampled_params()
random_point_dict = dict(zip(sampled_params_names, random_point))
random_point_dict['theta_MC_100']=1.0409
random_point_dict['omegak']=0
random_point_dict['Alens']=1.0
random_point_dict['Mag']=-19.253
random_point_dict['sigv']=240
random_point_dict['logA']=3.0448
random_point_dict['ns']=0.96605
random_point_dict['omegabh2']=0.022383
random_point_dict['omegach2']=0.12011
random_point_dict['tau']=0.0543
random_point_dict['A_planck']=1.00133

# %%
posterior_dict = model.logposterior(random_point_dict, as_dict=True)
posterior_dict
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 posterior_dict = model.logposterior(random_point_dict, as_dict=True)
#       2 posterior_dict
#
# File ~/cocoa/Cocoa/cobaya/cobaya/model.py:558, in Model.logposterior(self, params_values, as_dict, make_finite, return_derived, cached, _no_check)
#     555         logpriors.extend(self.prior.logps_external(input_params))
#     556 if -np.inf not in logpriors:
#     557     # noinspection PyUnboundLocalVariable
# --> 558     like = self._loglikes_input_params(input_params,
#     559                                        return_derived=return_derived,
#     560                                        cached=cached, make_finite=make_finite)
#     561     loglikes, derived_sampler = like if return_derived else (like, [])
#     562 else:
#
# ...

# %%
mylike = model.likelihood['mylike']
dir(model.likelihood['mylike'])
# Out:
# ['__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_at_resume_prefer_new',
#  '_at_resume_prefer_old',
#  '_enforce_types',
#  '_get_desc',
#  '_helpers',
#  '_input_params_extra',
#  '_input_params_order',
#  '_measured_speed',
#  '_name',
#  '_states',
#  'calculate',
#  'check_cache_and_compute',
#  'close',
#  'compare_versions',
#  'cov_PV_mod_8',
#  'cov_pan_fil',
#  'current_derived',
#  'current_logp',
#  'current_state',
#  'delay',
#  'file_base_name',
#  'get_allow_agnostic',
#  'get_annotations',
#  'get_associated_file_content',
# ...

# %%
mylike.provider.params
# Out:
# {'Mag': -19.253,
#  'sigv': 240.0,
#  'omegak': 0.0,
#  'Alens': 1.0,
#  'logA': 3.0448,
#  'As': 2.1005829616811546e-09,
#  'ns': 0.96605,
#  'theta_MC_100': 1.0409,
#  'cosmomc_theta': 0.010409,
#  'omegabh2': 0.022383,
#  'omegach2': 0.12011,
#  'mnu': 0.06,
#  'tau': 0.0543,
#  'w': -1.0,
#  'wa': 0.0,
#  'nrun': 0.0,
#  'nrunrun': 0.0,
#  'A_planck': 1.00133,
#  'cal100A': 1.0428785245934675,
#  'cal100B': 0.9874788213860888,
#  'cal143A': 1.0,
#  'cal143B': 1.0713386284814215,
#  'cal217A': 0.9848585709225497,
#  'cal217B': 1.0835815878666426,
#  'pe100A': 1.0,
#  'pe100B': 1.0,
#  'pe143A': 1.0,
#  'pe143B': 1.0,
#  'pe217A': 0.975,
#  'pe217B': 0.975,
#  'Aradio': 11.515203845834227,
#  'beta_radio': -0.8,
#  'Adusty': 33.94686597907315,
#  'beta_dusty': 1.7745598738912882,
#  'AdustT': 1.142203049900188,
#  'beta_dustT': 1.5327583287759894,
#  'AsyncT': 0.0,
#  'Acib': 9.168993158954382,
#  'beta_cib': 1.7745598738912882,
#  'Atsz': 28.500041536479216,
# ...
